# %%
# 加载环境变量
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 1.没有记忆时

# %%
from langchain.agents import create_agent

agent = create_agent(model = "deepseek-chat")

# %%
from langchain.messages import HumanMessage

# 第一次调用，告知AI我的信息
response = agent.invoke(
    {"messages": [HumanMessage(content="你好，我叫虎哥，我最喜欢猫猫。")]}
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='4b09af9d-8daa-4c34-a301-2c33f722f758'), AIMessage(content='虎哥你好！很高兴认识你！🐯✨  \n喜欢猫猫的人一定都有颗温柔的心呢～你家里有养猫吗？还是喜欢云吸各种猫咪？如果聊起猫的话题，我可以陪你分享很多有趣的知识或者表情包哦！😸', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 15, 'total_tokens': 71, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache', 'id': '5fa22a51-ba6b-419d-84d8-07eef6f41d04', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d713d-ae5d-7b40-a514-419d067866ca-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 56, 'total_tokens': 71, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
# 第二次调用，询问我的信息
response = agent.invoke(
    {"messages": [HumanMessage(content="我最喜欢什么动物?")]}
)

print(response)
# Out:
# {'messages': [HumanMessage(content='我最喜欢什么动物?', additional_kwargs={}, response_metadata={}, id='e239329d-be21-4981-9d54-56d10e78ad4f'), AIMessage(content='哈哈，这个问题可难倒我啦！作为一个人工智能，我无法直接了解你的个人喜好哦～😊\n\n不过我可以猜猜看：\n\n🐱 **猫咪** - 优雅独立，喜欢被宠爱\n🐶 **狗狗** - 忠诚热情，是人类最好的朋友\n🐼 **熊猫** - 憨态可掬，黑白配色超可爱\n🐬 **海豚** - 聪明友善，海洋中的微笑天使\n🦉 **猫头鹰** - 神秘智慧，夜晚的守护者\n\n或者你更喜欢一些特别的动物？比如：\n🦊 狐狸的机智\n🐨 考拉的慵懒\n🦋 蝴蝶的美丽\n🐋 鲸鱼的庞大\n\n**不如你告诉我吧！** 你最喜欢的动物是什么？我很想听听你的选择，还可以跟你分享关于这种动物的有趣知识呢！✨', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 182, 'prompt_tokens': 9, 'total_tokens': 191, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache', 'id': '4982f52a-f564-4bb0-925d-c27945bba7d2', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d713d-bfa2-78f1-8bd7-c5414bbc0c19-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 182, 'total_tokens': 191, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %% [markdown]
# # 2.添加记忆
#
# 添加会话记忆（短期记忆）分为三步：
# - 导入并初始化Checkpointer
# - 创建Agent，指定Checkpointer
# - 调用Agent，指定thread_id

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver


agent = create_agent(
    "deepseek-chat",
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

# 设定thread_id，作为会话标识
config = {"configurable": {"thread_id": "thread_1"}}

# 第一次调用，告知AI我的信息
response = agent.invoke(
    {"messages": [HumanMessage(content="你好，我叫虎哥，我最喜欢猫猫。")]},
    config # 调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='055d19b1-06b4-4238-a7c0-8932805dc0ee'), AIMessage(content='虎哥你好！很高兴认识你！🐯✨  \n喜欢猫猫的人一定都有颗温柔又有趣的心呢～你家里有养猫吗？还是云吸猫爱好者？如果聊起猫咪的可爱瞬间，我可有一堆“猫梗”可以分享哦！😸', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 59, 'prompt_tokens': 15, 'total_tokens': 74, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache', 'id': 'b8745e57-886f-4c32-81eb-8ede3b49c2b4', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d713d-e0e0-7a30-9e95-f28533039ee6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 59, 'total_tokens': 74, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
# 第二次调用，询问我的信息，这次带上thread_id，唤起记忆
response = agent.invoke(
    {"messages": [HumanMessage(content="我最喜欢的动物是什么？")]},
    config # 调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='055d19b1-06b4-4238-a7c0-8932805dc0ee'), AIMessage(content='虎哥你好！很高兴认识你！🐯✨  \n喜欢猫猫的人一定都有颗温柔又有趣的心呢～你家里有养猫吗？还是云吸猫爱好者？如果聊起猫咪的可爱瞬间，我可有一堆“猫梗”可以分享哦！😸', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 59, 'prompt_tokens': 15, 'total_tokens': 74, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache', 'id': 'b8745e57-886f-4c32-81eb-8ede3b49c2b4', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d713d-e0e0-7a30-9e95-f28533039ee6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 59, 'total_tokens': 74, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='我最喜欢的动物是什么？', additional_kwargs={}, response_metadata={}, id='f949710b-7731-457d-9b04-c4a25a558cff'), AIMessage(content='哈哈，这个问题可难不倒我——你最喜欢的动物当然是**猫猫**啦！🐱  \n毕竟你刚才已经说过“最喜欢猫猫”了～（机智如我，记性满分！）  \n\n不过如果你有其他偷偷喜欢的动物，比如大老虎（毕竟你是“虎哥”嘛！）、或者猫头鹰、小熊猫……我也很乐意听你分享哦！😄', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 82, 'prompt_tokens': 83, 'total_tokens': 165, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 83}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache', 'id': '703b58a9-1255-4051-839f-56d3a78db9a7', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d713d-ee66-7ae3-9b37-cdaccaee698d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 83, 'output_tokens': 82, 'total_tokens': 165, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %% [markdown]
# # 3.Memory持久化存储
#
# 这里我们选择使用Sqlite作为存储方案，首先需要按照langgraph-checkpoint-sqlite依赖：
# ```
# uv add langgraph-checkpoint-sqlite
# ```
# 接着，按照以下步骤使用：
# - 导入依赖
# - 初始化checkpointer
# - 自动建表
# - 创建Agent，指定checkpointer

# %%
import sqlite3
from langgraph.checkpoint.sqlite import SqliteSaver

# 连接sqlite
connection = sqlite3.connect("resources/checkpoint.db", check_same_thread=False)
# 初始化checkpointer
checkpointer = SqliteSaver(connection)
# 自动建表
checkpointer.setup()

# 创建agent
agent = create_agent(
    "deepseek-chat",
    checkpointer=checkpointer,
)

# %%
from langchain.messages import HumanMessage

# 设定thread_id，作为会话标识
config = {"configurable": {"thread_id": "thread_2"}}

# 第一次调用，告知AI我的信息
response = agent.invoke(
    {"messages": [HumanMessage(content="你好，我叫虎哥，我最喜欢猫猫。")]},
    config # 调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='abd24f82-3211-4093-bb04-a86c260bf615'), AIMessage(content='你好虎哥！喜欢猫猫的人一定都有颗温暖又柔软的心呢～🐱 猫猫那种优雅又带点小傲娇的性格，真的特别治愈！你家里有养猫吗？还是云吸猫爱好者呀？如果聊起猫咪的趣事或者养猫心得，我超想听的！ （顺便说，你的名字“虎哥”和“猫猫”莫名有种反差萌呢～）', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 89, 'prompt_tokens': 15, 'total_tokens': 104, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache', 'id': 'ab229ef4-db7d-4d98-91c6-debebb9d7124', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d7141-2d02-77d2-83a9-870cb9191795-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 89, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
# 第二次调用，询问我的信息，这次带上thread_id，唤起记忆
response = agent.invoke(
    {"messages": [HumanMessage(content="我最喜欢的动物是什么？")]},
    config # 调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='abd24f82-3211-4093-bb04-a86c260bf615'), AIMessage(content='你好虎哥！喜欢猫猫的人一定都有颗温暖又柔软的心呢～🐱 猫猫那种优雅又带点小傲娇的性格，真的特别治愈！你家里有养猫吗？还是云吸猫爱好者呀？如果聊起猫咪的趣事或者养猫心得，我超想听的！ （顺便说，你的名字“虎哥”和“猫猫”莫名有种反差萌呢～）', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 89, 'prompt_tokens': 15, 'total_tokens': 104, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache', 'id': 'ab229ef4-db7d-4d98-91c6-debebb9d7124', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d7141-2d02-77d2-83a9-870cb9191795-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 89, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='我最喜欢的动物是什么？', additional_kwargs={}, response_metadata={}, id='3fac6016-2f50-447c-932f-3993376ab5be'), AIMessage(content='根据我们之前的对话，你提到自己“最喜欢猫猫”，所以答案很明显啦——你最喜欢的动物是**猫猫**！🐱\n\n不过，如果这是个“陷阱题”……难道你后来偷偷爱上了“大猫”（比如老虎？毕竟你是“虎哥”嘛！）或者被其他小动物“篡位”了？😉 需要我帮你更新数据库吗？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 113, 'total_tokens': 194, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 113}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache', 'id': '19b594b8-8cdc-4d9f-82ff-6ec83a2512e2', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d7141-8219-7690-b146-eb17ce375ed5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 113, 'output_tokens': 81, 'total_tokens': 194, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %% [markdown]
# # 4.记忆管理
#
# 当会话历史过长时，可能会超出模型的上下文窗口限制，常见的解决方案有：
# - 修剪消息
# - 删除消息
# - 总结消息摘要
#
# 这里我们演示总结消息摘要的方案

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.runnables import RunnableConfig

# 初始化checkpointer
checkpointer = InMemorySaver()
# 初始化中间件
middleware = SummarizationMiddleware(
    model="deepseek-chat",
    trigger=("messages", 6), #  触发时机，当消息数超过3时，进行总结
    keep=("messages", 1) #  保留的会话数，超过2条
)
# 创建agent
agent = create_agent(
    model="deepseek-chat",
    middleware=[middleware],
    checkpointer=checkpointer,
)

config: RunnableConfig = {"configurable": {"thread_id": "thread_3"}}
# 制造长会话历史
agent.invoke({"messages": [HumanMessage(content="你好，我是虎哥.")]}, config)
agent.invoke({"messages": [HumanMessage(content="我最喜欢的运动是乒乓")]}, config)
agent.invoke({"messages": [HumanMessage(content="我最喜欢的动物是猫猫")]}, config)
# 测试效果
final_response = agent.invoke({"messages": HumanMessage(content="你还记得我吗？")}, config)

# %%
print(final_response)
# Out:
# {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\n用户“虎哥”正在进行一场开放式的对话。最初的兴趣点是乒乓球，但最新消息表明他最喜欢的动物是猫。当前意图是围绕“猫”这一新主题进行交流，并探索用户希望深入的具体方向（如品种、日常养护或文化）。\n\n## SUMMARY\n用户最初表示最喜欢的运动是乒乓球，AI提供了几个讨论方向（技术、赛事、日常）。然而，在最新互动中，用户明确表示最喜欢的动物是猫，话题已从乒乓球转移到猫。AI已回应并认可了新话题，提供了几个关于猫的可深入讨论方向：1) 品种趣谈，2) 养猫日常，3) 文化彩蛋。目前正等待用户从这些选项中选择或提出关于猫的新兴趣点。\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\n等待用户“虎哥”从AI提出的关于猫的几个话题方向中选择一个（例如品种、日常、文化）或分享自己与猫相关的具体经历、问题，以便展开更具体、深入的对话。', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='0579c2cc-3f92-4e00-9642-646d1ba4b00c'), HumanMessage(content='你还记得我吗？', additional_kwargs={}, response_metadata={}, id='a4f0d747-5fa6-46fe-8675-1ca9ee1fec12'), AIMessage(content='当然记得！虎哥，你之前提到最喜欢的运动是乒乓球，但后来又说最喜欢的动物是猫——看来你是个既爱运动又爱萌宠的人呢！😸  \n\n关于猫的话题，你更想聊聊品种趣闻、养猫日常，还是猫在文化中的有趣角色？或者你有其他关于猫的故事或问题想分享？我随时准备好“撸猫”式聊天啦～', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 84, 'prompt_tokens': 234, 'total_tokens': 318, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 234}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache', 'id': 'e66a57b6-8ac0-40ba-8de0-824ce961d5c9', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d72ca-abbe-7251-a980-619e5180a74e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 234, 'output_tokens': 84, 'total_tokens': 318, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
for message in final_response["messages"]:
    message.pretty_print()
